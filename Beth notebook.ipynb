# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
#Import Streaming dataframe from CSV
parks_df = pd.read_csv('parks.csv')
parks_df.head()
# Out:
#    OBJECTID PRKID                            PRKNAME              PRKADDR  \
# 0         1  CLAG      Clanton Park Community Garden    3010 BARRINGER DR
# 1         2  COLL                       Collins Park  4525 COLLINGWOOD DR
# 2         3  CTMY             C.T. Myers Golf Course   7817 HARRISBURG RD
# 3         4  THMP                      Thompson Park        1125 E 3RD ST
# 4         5  AMSG  Alexander Middle School Gymnasium   12010 HAMBRIGHT RD
#
#    STREETNO STREETDIR     STREETNM STREETTYPE STREETSUFF          CITY  ...  \
# 0      3010       NaN    BARRINGER         DR        NaN     CHARLOTTE  ...
# 1      4525            COLLINGWOOD         DR                CHARLOTTE  ...
# 2      7817             HARRISBURG         RD                CHARLOTTE  ...
# 3      1125         E          3RD         ST         NO     CHARLOTTE  ...
# 4     12010       NaN    HAMBRIGHT         RD        NaN  HUNTERSVILLE  ...
#
#   PRKAGE  PRKADAACC  CITYCOUNCI        BOCC                 PRKDATE USERID  \
# 0    NaN        NaN  District 3  District 2  2019/03/25 16:29:41+00    NaN
# 1    NaN        NaN  District 1  District 5  1998/07/28 00:00:00+00    NaN
# 2    NaN        NaN  District 5  District 4  2002/03/18 00:00:00+00    NaN
# 3    NaN        NaN  District 1  District 4  1998/09/02 00:00:00+00    NaN
# 4    NaN        NaN         NaN  District 1                     NaN    NaN
#
#    UPSIZE_TS            X            Y      LEASEDID
# 0        NaN  1437598.029  535681.4151   Mecklenburg
# 1        NaN  1440896.750  526061.0002   Mecklenburg
# 2        NaN  1496508.108  539832.7766   Mecklenburg
# 3        NaN  1452180.288  538692.2129   Mecklenburg
# 4        NaN  1452055.592  596972.0006  Huntersville
#
# [5 rows x 30 columns]

# %%
population_df = pd.read_csv('Charlotte_Pop_and_Income.csv')
population_df.head()
# Out:
#    zipcode  lattitude  longitude       city population pplpersqmile  \
# 0    28223  35.301946 -80.734737  Charlotte   3,265.00     7,150.18
# 1    28205  35.218791 -80.789601  Charlotte  46,301.00     3,876.93
# 2    28212  35.187703 -80.744556  Charlotte  35,367.00     3,802.06
# 3    28209  35.178714 -80.853985  Charlotte  19,759.00     3,638.25
# 4    28207  35.194148 -80.824585  Charlotte   8,691.00     3,435.91
#
#   avgincomeperhshd
# 0             -
# 1        34,240.00
# 2        37,151.00
# 3        46,175.00
# 4        84,232.00

# %%
parksandpop_df = pd.merge(parks_df, population_df, on="zipcode")
parksandpop_df
# Out:
#      OBJECTID PRKID                                    PRKNAME  \
# 0           1  CLAG              Clanton Park Community Garden
# 1          32  CLAN                               Clanton Park
# 2          44  SPRG                           Springfield Park
# 3          70  RSPK                           Renaissance Park
# 4         150  CLAP                  Dorothy D. Waddy Pavilion
# ..        ...   ...                                        ...
# 224       116  BCKP                            Back Creek Park
# 225       197  MLKR  Martin Luther King Jr. Middle School Site
# 226       215  NEWP                                Newell Park
# 227       274  SUGC              Sugaw Creek Recreation Center
# 228       281  HIDD                         Hidden Valley Park
#
#                            PRKADDR  STREETNO STREETDIR               STREETNM  \
# 0                3010 BARRINGER DR      3010       NaN              BARRINGER
# 1                  1520 CLANTON RD      1520                          CLANTON
# 2                 6700 DEANWOOD PL      6700                         DEANWOOD
# 3                 1536 W TYVOLA RD      1536         W                 TYVOLA
# 4               3132 MANCHESTER DR      3132       NaN             MANCHESTER
# ..                             ...       ...       ...                    ...
# 224      3343 BACK CREEK CHURCH RD         0                       NO ADDRESS
# 225                 500 BILMARK AV         0
# 226  9130 NEWELL BAPTIST CHURCH RD      9130            NEWELL BAPTIST CHURCH
# 227           943 W SUGAR CREEK RD       943         W            SUGAR CREEK
# 228              260 NORTHCHASE DR         0
#
#     STREETTYPE STREETSUFF       CITY  ... UPSIZE_TS            X            Y  \
# 0           DR        NaN  CHARLOTTE  ...       NaN  1437598.029  535681.4151
# 1           AV             CHARLOTTE  ...       NaN  1434491.148  536050.4650
# 2           PL             CHARLOTTE  ...       NaN  1431135.076  518528.0594
# 3           RD             CHARLOTTE  ...       NaN  1429340.235  524412.7907
# 4           DR        NaN  CHARLOTTE  ...       NaN  1437385.001  535127.0001
# ..         ...        ...        ...  ...       ...          ...          ...
# 224                        CHARLOTTE  ...       NaN  1492047.596  564895.0866
# 225                        CHARLOTTE  ...       NaN  1468942.507  555464.0724
# 226         RD             CHARLOTTE  ...       NaN  1482307.750  563623.7502
# 227         RD             CHARLOTTE  ...       NaN  1463875.508  558915.3095
# 228                    NO  CHARLOTTE  ...       NaN  1469748.130  555552.3194
#
#         LEASEDID  lattitude  longitude       city  population  pplpersqmile  \
# 0    Mecklenburg  35.168896 -80.908285  Charlotte   19,388.00      1,301.44
# 1    Mecklenburg  35.168896 -80.908285  Charlotte   19,388.00      1,301.44
# 2    Mecklenburg  35.168896 -80.908285  Charlotte   19,388.00      1,301.44
# 3    Mecklenburg  35.168896 -80.908285  Charlotte   19,388.00      1,301.44
# 4    Mecklenburg  35.168896 -80.908285  Charlotte   19,388.00      1,301.44
# ..           ...        ...        ...        ...         ...           ...
# 224  Mecklenburg  35.286034 -80.734355  Charlotte   25,882.00      1,907.01
# 225  Mecklenburg  35.286034 -80.734355  Charlotte   25,882.00      1,907.01
# 226  Mecklenburg  35.286034 -80.734355  Charlotte   25,882.00      1,907.01
# 227  Mecklenburg  35.286034 -80.734355  Charlotte   25,882.00      1,907.01
# 228  Mecklenburg  35.286034 -80.734355  Charlotte   25,882.00      1,907.01
#
#      avgincomeperhshd
# 0           38,757.00
# 1           38,757.00
# 2           38,757.00
# 3           38,757.00
# 4           38,757.00
# ..                ...
# 224         41,340.00
# 225         41,340.00
# 226         41,340.00
# 227         41,340.00
# 228         41,340.00
#
# [229 rows x 36 columns]

# %%
#Delete columns and confirm order of remaining columns
del parksandpop_df['STREETDIR']
del parksandpop_df['STREETSUFF']
del parksandpop_df['UPSIZE_TS']
del parksandpop_df['USERID']
del parksandpop_df['STREETTYPE']
del parksandpop_df['city']
parksandpop_df
# Out:
#      OBJECTID PRKID                                    PRKNAME  \
# 0           1  CLAG              Clanton Park Community Garden
# 1          32  CLAN                               Clanton Park
# 2          44  SPRG                           Springfield Park
# 225 -80.734355   25,882.00      1,907.01        41,340.00
# 226 -80.734355   25,882.00      1,907.01        41,340.00
# 227 -80.734355   25,882.00      1,907.01        41,340.00
# 228 -80.734355   25,882.00      1,907.01        41,340.00
#
# [229 rows x 30 columns]

# %%
#Delete columns and confirm order of remaining columns
del parksandpop_df['PRKSIZE']
del parksandpop_df['PRKXCOORD']
del parksandpop_df['PRKYCOORD']
del parksandpop_df['PRKAGE']
del parksandpop_df['PRKADAACC']
parksandpop_df.head()
# Out:
#    OBJECTID PRKID                        PRKNAME             PRKADDR  \
# 0         1  CLAG  Clanton Park Community Garden   3010 BARRINGER DR
# 1        32  CLAN                   Clanton Park     1520 CLANTON RD
# 2        44  SPRG               Springfield Park    6700 DEANWOOD PL
# 3        70  RSPK               Renaissance Park    1536 W TYVOLA RD
# 4       150  CLAP      Dorothy D. Waddy Pavilion  3132 MANCHESTER DR
#
#    STREETNO    STREETNM       CITY STATE  zipcode           PRKTYPE  ...  \
# 0      3010   BARRINGER  CHARLOTTE    NC    28217  Community Garden  ...
# 1      1520     CLANTON  CHARLOTTE    NC    28217         Community  ...
# 2      6700    DEANWOOD  CHARLOTTE    NC    28217      Neighborhood  ...
# 3      1536      TYVOLA  CHARLOTTE    NC    28217          Regional  ...
# 4      3132  MANCHESTER  CHARLOTTE    NC    28217          Pavilion  ...
#
#          BOCC                 PRKDATE            X            Y     LEASEDID  \
# 0  District 2  2019/03/25 16:29:41+00  1437598.029  535681.4151  Mecklenburg
# 1  District 2  1998/07/28 00:00:00+00  1434491.148  536050.4650  Mecklenburg
# 2  District 2  1998/07/28 00:00:00+00  1431135.076  518528.0594  Mecklenburg
# 3  District 2  2002/02/01 00:00:00+00  1429340.235  524412.7907  Mecklenburg
# 4  District 2  2019/02/25 16:36:18+00  1437385.001  535127.0001  Mecklenburg
#
#    lattitude  longitude  population  pplpersqmile avgincomeperhshd
# 0  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 1  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 2  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 3  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 4  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
#
# [5 rows x 25 columns]

# %%
#output to CSV
parksandpop_df.to_csv("parksandpop.csv", index=False, header=True)

# %%
parksandpop_df.head()
# Out:
#    OBJECTID PRKID                        PRKNAME             PRKADDR  \
# 0         1  CLAG  Clanton Park Community Garden   3010 BARRINGER DR
# 1        32  CLAN                   Clanton Park     1520 CLANTON RD
# 2        44  SPRG               Springfield Park    6700 DEANWOOD PL
# 3        70  RSPK               Renaissance Park    1536 W TYVOLA RD
# 4       150  CLAP      Dorothy D. Waddy Pavilion  3132 MANCHESTER DR
#
#    STREETNO    STREETNM       CITY STATE  zipcode           PRKTYPE  ...  \
# 0      3010   BARRINGER  CHARLOTTE    NC    28217  Community Garden  ...
# 1      1520     CLANTON  CHARLOTTE    NC    28217         Community  ...
# 2      6700    DEANWOOD  CHARLOTTE    NC    28217      Neighborhood  ...
# 3      1536      TYVOLA  CHARLOTTE    NC    28217          Regional  ...
# 4      3132  MANCHESTER  CHARLOTTE    NC    28217          Pavilion  ...
#
#          BOCC                 PRKDATE            X            Y     LEASEDID  \
# 0  District 2  2019/03/25 16:29:41+00  1437598.029  535681.4151  Mecklenburg
# 1  District 2  1998/07/28 00:00:00+00  1434491.148  536050.4650  Mecklenburg
# 2  District 2  1998/07/28 00:00:00+00  1431135.076  518528.0594  Mecklenburg
# 3  District 2  2002/02/01 00:00:00+00  1429340.235  524412.7907  Mecklenburg
# 4  District 2  2019/02/25 16:36:18+00  1437385.001  535127.0001  Mecklenburg
#
#    lattitude  longitude  population  pplpersqmile avgincomeperhshd
# 0  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 1  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 2  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 3  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 4  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
#
# [5 rows x 25 columns]

# %%
parksformat_df = parksandpop_df.rename(columns={'OBJECTID': 'objectid', 'PRKID': 'parkid', 'PRKNAME': 'parkname',
                                                'PRKADDR': 'parkaddress', 'STREETNO': 'streetno','STREETNM': 'streetname',
                                                'CITY': 'city', 'STATE': 'state', 'zipcode':'zipcode','PRKTYPE': 'parktype',
                                                'PRKCAT': 'parkcatagory', 'PRKSTATUS': 'parkstatus', 'PRKDIST': 'parkdist',
                                                'PRKPHONE': 'parkphone','CITYCOUNCI': 'councildistrict', 'BOCC': 'bocc',
                                                'PRKDATE': 'parkdate', 'X': 'x', 'Y': 'y', 'LEASEDID': 'leasedid',
                                                'Lattitude': 'lattitude', 'longitude': 'longitude', 'population': 'population',
                                                'pplpersqmile': 'pplpersqmile', 'avgincomeperhshd': 'avgincomeperhshd'})
parksformat_df.head()
# Out:
#    objectid parkid                       parkname         parkaddress  \
# 0         1   CLAG  Clanton Park Community Garden   3010 BARRINGER DR
# 1        32   CLAN                   Clanton Park     1520 CLANTON RD
# 2        44   SPRG               Springfield Park    6700 DEANWOOD PL
# 3        70   RSPK               Renaissance Park    1536 W TYVOLA RD
# 4       150   CLAP      Dorothy D. Waddy Pavilion  3132 MANCHESTER DR
#
#    streetno  streetname       city state  zipcode          parktype  ...  \
# 0      3010   BARRINGER  CHARLOTTE    NC    28217  Community Garden  ...
# 1      1520     CLANTON  CHARLOTTE    NC    28217         Community  ...
# 2      6700    DEANWOOD  CHARLOTTE    NC    28217      Neighborhood  ...
# 3      1536      TYVOLA  CHARLOTTE    NC    28217          Regional  ...
# 4      3132  MANCHESTER  CHARLOTTE    NC    28217          Pavilion  ...
#
#          bocc                parkdate            x            y     leasedid  \
# 0  District 2  2019/03/25 16:29:41+00  1437598.029  535681.4151  Mecklenburg
# 1  District 2  1998/07/28 00:00:00+00  1434491.148  536050.4650  Mecklenburg
# 2  District 2  1998/07/28 00:00:00+00  1431135.076  518528.0594  Mecklenburg
# 3  District 2  2002/02/01 00:00:00+00  1429340.235  524412.7907  Mecklenburg
# 4  District 2  2019/02/25 16:36:18+00  1437385.001  535127.0001  Mecklenburg
#
#    lattitude  longitude  population  pplpersqmile avgincomeperhshd
# 0  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 1  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 2  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 3  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
# 4  35.168896 -80.908285   19,388.00      1,301.44        38,757.00
#
# [5 rows x 25 columns]

# %%
#output to CSV
parksformat_df.to_csv("parksdataframe.csv", index=False, header=True)

# %%
rds_connection_string = "postgres:Jacky0509@localhost:5432/parks_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['parks']

# %%
parksformat_df.to_sql(name='parks', con=engine, if_exists='append', index=False)
